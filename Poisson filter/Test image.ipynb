# %%
from Poisson_filter import poisson_filter
import cv2 as cv
import numpy as np

# %%
img = cv.imread('photo.jpeg', cv.IMREAD_GRAYSCALE )
height, width = img.shape
arr = np.array([img.reshape(height*width)])

res = poisson_filter.spike_generator(arr, 10, 0.1, 10)
poisson_filter.raster_plot_spike(res)
